# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-LLC/FinRL-Library/blob/master/Crypto_Binance_Historical_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fetch historical data

# %% [markdown]
# Python script to fetch historical data from binance using ccxt

# %%
# Install openpyxl and CCXT
# !pip install openpyxl ccxt
# Out:
# Collecting ccxt
#   Downloading ccxt-1.50.69-py2.py3-none-any.whl (2.0 MB)
#      |################################| 2.0 MB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.18.4 in /opt/conda/lib/python3.6/site-packages (from ccxt) (2.24.0)
# Requirement already satisfied: certifi>=2018.1.18 in /opt/conda/lib/python3.6/site-packages (from ccxt) (2020.12.5)
# Requirement already satisfied: setuptools>=38.5.1 in /opt/conda/lib/python3.6/site-packages (from ccxt) (51.0.0.post20201207)
# Requirement already satisfied: cryptography>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from ccxt) (3.3.1)
# Collecting yarl==1.6.3
#   Downloading yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293 kB)
#      |################################| 293 kB 17.9 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.6/site-packages (from yarl==1.6.3->ccxt) (3.7.4.3)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.6/site-packages (from yarl==1.6.3->ccxt) (2.10)
# Collecting aiodns<2.1,>=1.1.1
#   Downloading aiodns-2.0.0-py2.py3-none-any.whl (4.8 kB)
# Collecting aiohttp<3.8,>=3.7.4
#   Downloading aiohttp-3.7.4.post0-cp36-cp36m-manylinux2014_x86_64.whl (1.3 MB)
#      |################################| 1.3 MB 15.2 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.6/site-packages (from aiohttp<3.8,>=3.7.4->ccxt) (20.3.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /opt/conda/lib/python3.6/site-packages (from aiohttp<3.8,>=3.7.4->ccxt) (3.0.4)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.6/site-packages (from cryptography>=2.6.1->ccxt) (1.14.4)
# Requirement already satisfied: six>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from cryptography>=2.6.1->ccxt) (1.15.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.20)
# Collecting idna-ssl>=1.0
#   Downloading idna-ssl-1.1.0.tar.gz (3.4 kB)
# Collecting multidict>=4.0
#   Downloading multidict-5.1.0-cp36-cp36m-manylinux2014_x86_64.whl (141 kB)
#      |################################| 141 kB 11.2 MB/s eta 0:00:01
# Collecting pycares>=3.0.0
#   Downloading pycares-4.0.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
#      |################################| 291 kB 9.0 MB/s eta 0:00:01
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests>=2.18.4->ccxt) (1.25.11)
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |################################| 243 kB 19.5 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |################################| 78 kB 2.8 MB/s  eta 0:00:01
# Building wheels for collected packages: idna-ssl, typing
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-py3-none-any.whl size=3161 sha256=60db227d2e3ff4e52393ec528a08fa6b7812bd859d678cfa2c7fac015ba89154
#   Stored in directory: /root/.cache/pip/wheels/6a/f5/9c/f8331a854f7a8739cf0e74c13854e4dd7b1af11b04fe1dde13
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26308 sha256=03a802f7f03273e6d21648ef41982c65c182ee8fcd7cffb65bde16897667d5e2
#   Stored in directory: /root/.cache/pip/wheels/5f/63/c2/b85489bbea28cb5d36cfe197244f898428004fa3caa7a23116
# Successfully built idna-ssl typing
# Installing collected packages: multidict, yarl, typing, pycares, idna-ssl, async-timeout, et-xmlfile, aiohttp, aiodns, openpyxl, ccxt
# Successfully installed aiodns-2.0.0 aiohttp-3.7.4.post0 async-timeout-3.0.1 ccxt-1.50.69 et-xmlfile-1.1.0 idna-ssl-1.1.0 multidict-5.1.0 openpyxl-3.0.7 pycares-4.0.0 typing-3.7.4.3 yarl-1.6.3

# %%
import os
from pathlib import Path

import sys
import csv
import pandas as pd

# -----------------------------------------------------------------------------

root = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(''))))
sys.path.append(root + '/python')

import ccxt


# -----------------------------------------------------------------------------

def retry_fetch_ohlcv(exchange, max_retries, symbol, timeframe, since, limit):
    num_retries = 0
    try:
        num_retries += 1
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit)
        # print('Fetched', len(ohlcv), symbol, 'candles from', exchange.iso8601 (ohlcv[0][0]), 'to', exchange.iso8601 (ohlcv[-1][0]))
        return ohlcv
    except Exception:
        if num_retries > max_retries:
            raise  # Exception('Failed to fetch', timeframe, symbol, 'OHLCV in', max_retries, 'attempts')


def scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit):
    earliest_timestamp = exchange.milliseconds()
    timeframe_duration_in_seconds = exchange.parse_timeframe(timeframe)
    timeframe_duration_in_ms = timeframe_duration_in_seconds * 1000
    timedelta = limit * timeframe_duration_in_ms
    all_ohlcv = []
    while True:
        fetch_since = earliest_timestamp - timedelta
        ohlcv = retry_fetch_ohlcv(exchange, max_retries, symbol, timeframe, fetch_since, limit)
        # if we have reached the beginning of history
        if ohlcv[0][0] >= earliest_timestamp:
            break
        earliest_timestamp = ohlcv[0][0]
        all_ohlcv = ohlcv + all_ohlcv
        print(len(all_ohlcv), symbol, 'candles in total from', exchange.iso8601(all_ohlcv[0][0]), 'to', exchange.iso8601(all_ohlcv[-1][0]))
        # if we have reached the checkpoint
        if fetch_since < since:
            break
    return all_ohlcv


def write_to_csv(filename, exchange, data):
    p = Path("./data/raw/", str(exchange))
    p.mkdir(parents=True, exist_ok=True)
    full_path = p / str(filename)
    with Path(full_path).open('w+', newline='') as output_file:
        csv_writer = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        csv_writer.writerows(data)


def scrape_candles_to_csv(filename, exchange_id, max_retries, symbol, timeframe, since, limit):
    # instantiate the exchange by id
    exchange = getattr(ccxt, exchange_id)({
        'enableRateLimit': True,  # required by the Manual
    })
    # convert since from string to milliseconds integer if needed
    if isinstance(since, str):
        since = exchange.parse8601(since)
    # preload all markets from the exchange
    exchange.load_markets()
    # fetch all candles
    ohlcv = scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit)
    # save them to csv file
    write_to_csv(filename, exchange, ohlcv)
    print('Saved', len(ohlcv), 'candles from', exchange.iso8601(ohlcv[0][0]), 'to', exchange.iso8601(ohlcv[-1][0]), 'to', filename)
    
    
def scrape_candles_to_df(filename, exchange_id, max_retries, symbol, timeframe, since, limit):
    # instantiate the exchange by id
    exchange = getattr(ccxt, exchange_id)({
        'enableRateLimit': True,  # required by the Manual
    })
    # convert since from string to milliseconds integer if needed
    if isinstance(since, str):
        since = exchange.parse8601(since)
    # preload all markets from the exchange
    exchange.load_markets()
    # fetch all candles
    ohlcv = scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit)
    # save them to df
    data_df = pd.DataFrame(data=ohlcv)
    return data_df

# %%
data = scrape_candles_to_df('btc_usdt_1m.csv', 'binance', 3, 'BTC/USDT', '1m', '2021-05-0100:00:00Z', 1000)
# scrape_candles_to_csv('./data/raw/binance/eth_btc_1m.csv', 'binance', 3, 'ETH/BTC', '1m', '2018-01-01T00:00:00Z', 1000)
# scrape_candles_to_csv('./data/raw/binance/ltc_btc_1m.csv', 'binance', 3, 'LTC/BTC', '1m', '2018-01-01T00:00:00Z', 1000)
# scrape_candles_to_csv('./data/raw/binance/xlm_btc_1m.csv', 'binance', 3, 'XLM/BTC', '1m', '2018-01-01T00:00:00Z', 1000)
data.head()
# Out:
# 1000 BTC/USDT candles in total from 2021-05-30T04:31:00.000Z to 2021-05-30T21:10:00.000Z
# 2000 BTC/USDT candles in total from 2021-05-29T11:51:00.000Z to 2021-05-30T21:10:00.000Z
# 3000 BTC/USDT candles in total from 2021-05-28T19:11:00.000Z to 2021-05-30T21:10:00.000Z
# 4000 BTC/USDT candles in total from 2021-05-28T02:31:00.000Z to 2021-05-30T21:10:00.000Z
# 34000 BTC/USDT candles in total from 2021-05-07T06:31:00.000Z to 2021-05-30T21:10:00.000Z
# 35000 BTC/USDT candles in total from 2021-05-06T13:51:00.000Z to 2021-05-30T21:10:00.000Z
# 36000 BTC/USDT candles in total from 2021-05-05T21:11:00.000Z to 2021-05-30T21:10:00.000Z
# 37000 BTC/USDT candles in total from 2021-05-05T04:31:00.000Z to 2021-05-30T21:10:00.000Z
# 38000 BTC/USDT candles in total from 2021-05-04T11:51:00.000Z to 2021-05-30T21:10:00.000Z
# 39000 BTC/USDT candles in total from 2021-05-03T19:11:00.000Z to 2021-05-30T21:10:00.000Z
# 40000 BTC/USDT candles in total from 2021-05-03T02:31:00.000Z to 2021-05-30T21:10:00.000Z
# 41000 BTC/USDT candles in total from 2021-05-02T09:51:00.000Z to 2021-05-30T21:10:00.000Z
# 42000 BTC/USDT candles in total from 2021-05-01T17:11:00.000Z to 2021-05-30T21:10:00.000Z
# 43000 BTC/USDT candles in total from 2021-05-01T00:31:00.000Z to 2021-05-30T21:10:00.000Z
# 44000 BTC/USDT candles in total from 2021-04-30T07:51:00.000Z to 2021-05-30T21:10:00.000Z
#                0         1         2         3         4          5
# 0  1619769060000  54283.73  54286.00  54261.42  54267.52  25.456899
# 1  1619769120000  54267.51  54273.36  54263.74  54264.47  25.162633
# 2  1619769180000  54264.48  54272.67  54261.44  54268.82  19.513919
# 3  1619769240000  54268.82  54304.21  54264.00  54280.33  34.360138
# 4  1619769300000  54280.32  54304.20  54275.15  54291.79  29.218204

# %%
data.columns = [
                "date",
                "open",
                "high",
                "low",
                "close",
             
                "volume",
          
            ]

# %%
data.head()
# Out:
#             date      open      high       low     close     volume
# 0  1619769060000  54283.73  54286.00  54261.42  54267.52  25.456899
# 1  1619769120000  54267.51  54273.36  54263.74  54264.47  25.162633
# 2  1619769180000  54264.48  54272.67  54261.44  54268.82  19.513919
# 3  1619769240000  54268.82  54304.21  54264.00  54280.33  34.360138
# 4  1619769300000  54280.32  54304.20  54275.15  54291.79  29.218204

# %%
data["tic"] = "BTC/USDT"
data.head()
# Out:
#             date      open      high       low     close     volume       tic
# 0  1619769060000  54283.73  54286.00  54261.42  54267.52  25.456899  BTC/USDT
# 1  1619769120000  54267.51  54273.36  54263.74  54264.47  25.162633  BTC/USDT
# 2  1619769180000  54264.48  54272.67  54261.44  54268.82  19.513919  BTC/USDT
# 3  1619769240000  54268.82  54304.21  54264.00  54280.33  34.360138  BTC/USDT
# 4  1619769300000  54280.32  54304.20  54275.15  54291.79  29.218204  BTC/USDT

# %%
data["day"] = data["date"].dt.dayofweek
        # convert date to standard string format, easy to filter
data["date"] = data.date.apply(lambda x: x.strftime("%Y-%m-%d"))
data.head()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-17-c3acf717a052> in <module>
# ----> 1 data["day"] = data["date"].dt.dayofweek
#       2         # convert date to standard string format, easy to filter
#       3 data["date"] = data.date.apply(lambda x: x.strftime("%Y-%m-%d"))
#       4 data.head()
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5135             or name in self._accessors
#    5136         ):
# -> 5137             return object.__getattribute__(self, name)
#    5138         else:
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     478             return PeriodProperties(data, orig)
#     479
# --> 480         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values
